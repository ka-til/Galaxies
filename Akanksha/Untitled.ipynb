# %%
import fitsio
columns = ['PLATE', 'MJD', 'FIBERID', 'Z', 'ZWARNING', 'Z_ERR']
d = fitsio.read('spAll-v5_10_0.fits', columns=columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2524/1892050560.py in <module>
# ----> 1 import fitsio
#       2 columns = ['PLATE', 'MJD', 'FIBERID', 'Z', 'ZWARNING', 'Z_ERR']
#       3 d = fitsio.read('spAll-v5_10_0.fits', columns=columns)
#
# ModuleNotFoundError: No module named 'fitsio'

# %%
from astropy.io import fits
hdul = fits.open('MAST_2021-10-30T1757/MAST_2021-10-30T1757/HST/j9op04010/j9op04010_drc.fits')

# %%
hdul.info()
# Out:
# Filename: MAST_2021-10-30T1757/MAST_2021-10-30T1757/HST/j9op04010/j9op04010_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     849   ()
#   1  SCI           1 ImageHDU        93   (4219, 4242)   float32
#   2  WHT           1 ImageHDU        44   (4219, 4242)   float32
#   3  CTX           1 ImageHDU        37   (4219, 4242)   int32
# ...

# %%
hdul.close()

# %%
with fits.open('MAST_2021-10-30T1757/MAST_2021-10-30T1757/HST/j9op04010/j9op04010_drc.fits') as hdul:
    hdul.verify('fix')
    data = hdul[1].data

# %%
data
# Out:
# array([[        nan,         nan, -0.01697766, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan, -0.0168825 , ...,         nan,
#                 nan,         nan],
#        [-0.01587887,  0.00550852,  0.01971406, ...,         nan,
#                 nan,         nan],
#        ...,
#        [        nan,         nan,         nan, ...,  0.03165575,
#          0.00195855,  0.00492561],
#        [        nan,         nan,         nan, ...,  0.03318588,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,  0.00989629,
#          0.01164266,         nan]], dtype=float32)

# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits

image_file = get_pkg_data_filename('MAST_2021-10-30T1757/MAST_2021-10-30T1757/HST/j9op04010/j9op04010_drz.fits')

# %%
fits.info(image_file)
# Out:
# Filename: MAST_2021-10-30T1757\MAST_2021-10-30T1757\HST\j9op04010\j9op04010_drz.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     828   ()
#   1  SCI           1 ImageHDU        90   (4219, 4242)   float32
#   2  WHT           1 ImageHDU        44   (4219, 4242)   float32
#   3  CTX           1 ImageHDU        37   (4219, 4242)   int32
# ...

# %%
image_data = fits.getdata(image_file, ext=1)

# %%
print(image_data.shape)
# Out:
# (4242, 4219)

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(image_data, cmap='gray')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="574.4444596620258">
