# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
from scipy import interpolate

# %%
dataframe = pd.read_excel("Focus2006.xlsx")

# %%
#Interpolation function(Modified Julian and Focus are given)
focus_fcn = interpolate.interp1d(dataframe['Julian '], dataframe['Focus'],)
focus_oct_fcn = interpolate.interp1d(dataframe['Julian '][(dataframe['Julian ']>54009.00000000) & (dataframe['Julian ']<54039.9999999)], dataframe['Focus'][(dataframe['Julian ']>54009.00000000) & (dataframe['Julian ']<54039.9999999)])

# %%
#modied julian dates with interval of 10 mins, the exposure period is about 2088 seconds. 
#The first value of array is the start time from https://mast.stsci.edu/portal/Mashup/Clients/Mast/Portal.html
oct_vals = np.array([54010.79328704, 54010.80023148, 54010.80717593, 54010.81412037])
focus_oct_vals = focus_fcn(oct_vals)
#focus_oct_fcn_vals = focus_oct_fcn(oct_vals)

# %%
# %matplotlib notebook
plt.plot(dataframe['Julian '], dataframe['Focus'], '.')
plt.plot(oct_vals, focus_oct_vals, '.')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
#Trying to check the mean focus for september, oct, dec and Jan.
'''
Modified Julian dates taken from - https://heasarc.gsfc.nasa.gov/cgi-bin/Tools/xTime/xTime.pl?time_in_i=2007-01-01+00%3A00%3A00&time_in_c=&time_in_d=&time_in_j=&time_in_m=&time_in_sf=&time_in_wf=&time_in_ii=&time_in_sl=&time_in_sni=&time_in_snu=&time_in_s=&time_in_h=&time_in_sz=&time_in_ss=&time_in_sn=&previous_input=2006-12-01+00%3A00%3A00&previous_input_ts=u&previous_input_tf=i&previous_input_gps_secs=848966414.000&timesys_in=u&timesys_out=u&apply_clock_offset=yes

'''

mean_focus_sept = np.mean(dataframe['Focus'][(dataframe['Julian ']>53979.00000000) & (dataframe['Julian ']<	54008.999999)])

mean_focus_oct = np.mean(dataframe['Focus'][(dataframe['Julian ']>54009.00000000) & (dataframe['Julian ']<54039.9999999)])

mean_focus_dec = np.mean(dataframe['Focus'][(dataframe['Julian ']>54070.00000000) & (dataframe['Julian ']<54101.00000000)])

mean_focus_jan = np.mean(dataframe['Focus'][(dataframe['Julian ']>53736.00000000) & (dataframe['Julian ']<53767.00000000)])

# %% [markdown]
# # SLACS1

# %%
mean_focus_sept, mean_focus_oct
# Out:
# (0.8912783346487774, 0.8327552992069217)

# %%
total_focus = np.mean(focus_oct_vals)
print(total_focus+0.09) #0.09 for ACS WFC1
# Out:
# -0.7765668337488701

# %%
#### y axis - 3178
2048 - (2*2048 - 3178)
# Out:
# 1130

# %% [markdown]
# # SLACS2

# %%
jan_vals = np.array([53758.683344917, 53758.69028935, 53758.69723380, 53758.70417824])
focus_jan_vals = focus_fcn(jan_vals)

# %%
total_focus_jan = np.mean(focus_jan_vals)
print(total_focus_jan+0.09) #0.09 for ACS WFC1
# Out:
# -3.776238538496939

# %% [markdown]
# # SLACS3

# %%
dec_vals = np.array([54087.09103009, 54087.09797454, 54087.10491898, 54087.11186343])
focus_dec_vals = focus_fcn(dec_vals)

# %%
total_focus_dec = np.mean(focus_dec_vals)
print(total_focus_dec+0.09) #0.09 for ACS WFC1
# Out:
# 0.548989850419814
