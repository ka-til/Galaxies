# %%
import numpy as np
from astropy.io import fits
from astropy.convolution import convolve
from astropy.wcs import WCS
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
plt.style.use(astropy_mpl_style)
import data_reduction

# %% [markdown]
# # SLACS2

# %%
SLACS2 = data_reduction.data_reduction(filepath='SLACS2_data/MAST_2021-12-16T1608/HST/j9c713020/', filename='j9c713020_drc', RA='12 50 28.251', DEC='+5 23 49.04')
# Out:
# Reading the fits file.
# Input RA: 12 50 28.251 Input DEC: +5 23 49.04

# %%
SLACS2.crop(cropsize=150)
# Out:
# New RA in degrees: 192.6177125 New DEC in degrees: 5.396955555555556
# Center coords: 2190.0406153655654 3176.310218043958
# Rounded pixel coord center values: 2190 3176

# %%
2047 - (2*2047 - 3176)
# Out:
# 1129

# %%
SLACS2.convolve(psffile='../../galaxies_software/tinytim/SLACS200.fits')

# %%
SLACS2.writefile(outfilepath='./SLACS2_new/')
# Out:
# C:\Users\akank\OneDrive - University of Waterloo\Fall 2021 Courses\PHYS 474\Submissions\Galaxies\Akanksha\data_reduction.py:143: RuntimeWarning: divide by zero encountered in true_divide
#   poisson_dist = self.hdul[1].data/np.random.poisson((self.hdul['SCI'].header['SNRMEAN']), self.hdul[1].data.shape)

# %%
SLACS2.plot_images(outfilepath='./SLACS2_new/')
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Users\akank\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
hdul_slacs2 = fits.open('./SLACS2_data/MAST_2021-12-16T1608/HST/j9c713020/j9c713020_drc.fits')

hdul_slacs2.info()

cs= 75
x1 = 2190-cs
x2 = 2190+cs

y1 = 3176-cs
y2 = 3176+cs

plt.imshow(hdul_slacs2[1].data[y1:y2,x1:x2], cmap='gray', norm=LogNorm())
# Out:
# Filename: ./SLACS2_data/MAST_2021-12-16T1608/HST/j9c713020/j9c713020_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     849   ()
#   1  SCI           1 ImageHDU        93   (4221, 4243)   float32
#   2  WHT           1 ImageHDU        44   (4221, 4243)   float32
#   3  CTX           1 ImageHDU        37   (4221, 4243)   int32
# ...

# %%
SLACS3 = data_reduction.data_reduction(filepath='SLACS3_data/MAST_2021-12-16T1611/HST/j9op36010/', filename='j9op36010_drc', RA='14 30 4.089', DEC='+41 5 57.13')
# Out:
# Reading the fits file.
# Input RA: 14 30 4.089 Input DEC: +41 5 57.13

# %%
SLACS3.crop(cropsize=150)
# Out:
# New RA in degrees: 217.5170375 New DEC in degrees: 41.09920277777778
# Center coords: 2192.4820013072745 3180.9588136840816
# Rounded pixel coord center values: 2192 3181

# %%
2047 - (2*2047 - 3181)
# Out:
# 1134

# %%
SLACS3.convolve(psffile='../../galaxies_software/tinytim/SLACS300.fits')

# %%
SLACS3.writefile(outfilepath='./SLACS3_new/')
# Out:
# C:\Users\akank\OneDrive - University of Waterloo\Fall 2021 Courses\PHYS 474\Submissions\Galaxies\Akanksha\data_reduction.py:143: RuntimeWarning: divide by zero encountered in true_divide
#   poisson_dist = self.hdul[1].data/np.random.poisson((self.hdul['SCI'].header['SNRMEAN']), self.hdul[1].data.shape)

# %%
SLACS3.plot_images(outfilepath='./SLACS3_new/')
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Users\akank\anaconda3\lib\site-packages\matplotlib\colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
hdul_slacs3 = fits.open('./SLACS3_data/MAST_2021-12-16T1611/HST/j9op36010/j9op36010_drc.fits')
hdul_slacs3.info()

cs= 75
x1 = 2192-cs
x2 = 2192+cs

y1 = 3181-cs
y2 = 3181+cs

plt.imshow(hdul_slacs3[1].data[y1:y2,x1:x2], cmap='gray', norm=LogNorm())
# Out:
# Filename: ./SLACS3_data/MAST_2021-12-16T1611/HST/j9op36010/j9op36010_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     849   ()
#   1  SCI           1 ImageHDU        93   (4221, 4242)   float32
#   2  WHT           1 ImageHDU        44   (4221, 4242)   float32
#   3  CTX           1 ImageHDU        37   (4221, 4242)   int32
# ...
